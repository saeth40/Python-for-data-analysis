# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %% [markdown]
# # Series

# %%
obj = pd.Series([4,7,-5,3])
obj

#Series = 1D array
#left side = indexs, right side = values
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
#index, values
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
#define index
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2.values
# Out:
# array([ 4,  7, -5,  3])

# %%
#pulling values from index
obj2['b']
# Out:
# 7

# %%
obj2[['d','a','c']]
# Out:
# d    4
# a   -5
# c    3
# dtype: int64

# %%
#change values 
obj2['d']=6
obj2
# Out:
# d    6
# b    7
# a   -5
# c    3
# dtype: int64

# %%
#boolean
obj2>0
# Out:
# d     True
# b     True
# a    False
# c     True
# dtype: bool

# %%
#return boolean values
obj2[obj2>0]
# Out:
# d    6
# b    7
# c    3
# dtype: int64

# %%
#Series calculation
obj2*2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %%
np.exp(obj2)
# Out:
# d     403.428793
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
# search index in Series
'b' in obj2
# Out:
# True

# %%
'e' in obj2
# Out:
# False

# %%
#create Series from dict
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
#{indexs:values}
obj3 = pd.Series(sdata)
obj3 #will display in order of dict
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
# redefine index 
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4 # will display in order of index
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
# detecting missing data (in this case is Califirnia)
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj4.isnull() #this code also work
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
# in other word, we can detect non-missing data
pd.notnull(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
# join operation in Series
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj3+obj4
# join operation
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
# define name to Series
obj4.name = 'population'
obj4.index.name = 'state'
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %% [markdown]
# # DataFrame

# %%
# = many Series which share the same index

#creating Dataframe from dict
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
 'year': [2000, 2001, 2002, 2001, 2002, 2003],
 'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
# all list must have the same length
frame = pd.DataFrame(data)
frame

#column will display in order
#shared the same index
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
#show the first 5 rows of data
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
# reorder column 
pd.DataFrame(data, columns=['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
 #apply index and new column
 frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'], index= ['one', 'two', 'three', 'four','five','six'])
 frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
#show column
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
#show index like Series
frame2.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
#pull column from Dataframe
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
frame2[['year','state']]
# Out:
#        year   state
# one    2000    Ohio
# two    2001    Ohio
# three  2002    Ohio
# four   2001  Nevada
# five   2002  Nevada
# six    2003  Nevada

# %%
#pulling row from Dataframe
frame2.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
#adding values in column
frame2['debt'] = 16.5
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
# six    2003  Nevada  3.2  16.5

# %%
frame2['debt'] = np.arange(6)
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5     0
# two    2001    Ohio  1.7     1
# three  2002    Ohio  3.6     2
# four   2001  Nevada  2.4     3
# five   2002  Nevada  2.9     4
# six    2003  Nevada  3.2     5

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
# adding and deleting columns
frame2['eastern'] = frame2.state == 'Ohio'
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Nevada  3.2   NaN    False

# %%
del frame2['eastern']
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
#creating dataframe from dict of dict
pop = {'Nevada': {2001: 2.4, 2002: 2.9},'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}
#this contains columns, index and column values
frame3 = pd.DataFrame(pop)
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %%
#Transpose
frame3.T
# Out:
#         2001  2002  2000
# Nevada   2.4   2.9   NaN
# Ohio     1.7   3.6   1.5

# %%
pd.DataFrame(pop, index=[2001, 2002, 2003])
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2003     NaN   NaN

# %%
frame3['Ohio']
# Out:
# 2001    1.7
# 2002    3.6
# 2000    1.5
# Name: Ohio, dtype: float64

# %%
frame3['Ohio'][:-1] #pull data from first one to the second last one
# Out:
# 2001    1.7
# 2002    3.6
# Name: Ohio, dtype: float64

# %%
frame3['Nevada'][:2]
# Out:
# 2001    2.4
# 2002    2.9
# Name: Nevada, dtype: float64

# %%
pdata = {'Ohio': frame3['Ohio'][:-1],'Nevada': frame3['Nevada'][:2]}
pd.DataFrame(pdata)
# Out:
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
# define name
frame3.index.name = 'year'; frame3.columns.name = 'state'
frame3
# Out:
# state  Nevada  Ohio
# year
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
#value
frame3.values
# Out:
# array([[2.4, 1.7],
#        [2.9, 3.6],
#        [nan, 1.5]])

# %%
frame3.index
# Out:
# Int64Index([2001, 2002, 2000], dtype='int64', name='year')

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
frame2.values
# Out:
# array([[2000, 'Ohio', 1.5, nan],
#        [2001, 'Ohio', 1.7, -1.2],
#        [2002, 'Ohio', 3.6, nan],
#        [2001, 'Nevada', 2.4, -1.5],
#        [2002, 'Nevada', 2.9, -1.7],
#        [2003, 'Nevada', 3.2, nan]], dtype=object)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Index Objects

# %%
obj = pd.Series(range(3), index=['a', 'b', 'c'])
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obj.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
obj.index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
#obj.index[1] = 'lol' will caues error (not mutable)

# %%
#define Index
labels = pd.Index(np.arange(3))
labels
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
obj2 = pd.Series([1.5, -2.5, 0], index=labels)
obj2
# Out:
# 0    1.5
# 1   -2.5
# 2    0.0
# dtype: float64

# %%
obj2.index is labels
# Out:
# True

# %%
frame3
# Out:
# state  Nevada  Ohio
# year
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
frame3.columns
# Out:
# Index(['Nevada', 'Ohio'], dtype='object', name='state')

# %%
'Ohio' in frame3.columns
# Out:
# True

# %%
2003 in frame3.index
# Out:
# False

# %%
#index can be duplicated
dup_labels = pd.Index(['foo', 'foo', 'bar', 'bar'])
dup_labels
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Reindexing

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
#forward-fills 'ffill'
obj3.reindex(range(6), method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),index=['a', 'c', 'd'],
                     columns=['Ohio', 'Texas', 'California'])
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame2 = frame.reindex(['a', 'b', 'd', 'c'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# d   6.0    7.0         8.0
# c   3.0    4.0         5.0

# %%
#reindex by column
states = ['Texas', 'Utah', 'California']
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
#pulling row
frame.loc['c']
# Out:
# Ohio          3
# Texas         4
# California    5
# Name: c, dtype: int64

# %%
frame.loc[['a','d']]
# Out:
#    Ohio  Texas  California
# a     0      1           2
# d     6      7           8

# %%
#pullin row and column
frame.loc[['a','d'],['Ohio','Texas']]
# Out:
#    Ohio  Texas
# a     0      1
# d     6      7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # *Dropping Entries from an Axis*

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
#deleting row
new_obj = obj.drop('c')
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop(['d', 'c'])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
obj #unmutated
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['Colorado', 'Ohio'])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
# axis = 1 : column (Y)
data.drop('two', axis=1)
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop(['two', 'four'], axis='columns')
# Out:
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utah        8     10
# New York   12     14

# %%
# inplace = True : permanantly mutated
obj.drop('c', inplace=True)
obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %% [markdown]
# # Indexing, Selection, and Filtering

# %%
obj = pd.Series(np.arange(4.), index=['a', 'b', 'c', 'd'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
#pilling from index 'b'
obj['b']
# Out:
# 1.0

# %%
#pulling from index=0 ('a')
obj[0]
# Out:
# 0.0

# %%
obj[2:4] #[2,4)
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
obj[['b', 'a', 'd']]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
obj[[1, 3]]
# Out:
# b    1.0
# d    3.0
# dtype: float64

# %%
#boolean index
obj[obj < 2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
obj['b':'c'] # end point = inclusive ['b','c'] not ['b','c')
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
#changing values
obj['b':'c'] = 5
obj
# Out:
# a    0.0
# b    5.0
# c    5.0
# d    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
#pulling column
data['one']
# Out:
# Ohio         0
# Colorado     4
# Utah         8
# New York    12
# Name: one, dtype: int64

# %%
data[['three', 'one']]
# Out:
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12

# %%
#puling row
data[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
data[data['three'] > 5]
# select all from data which column'three'>5
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data>5
# Out:
#             one    two  three   four
# Ohio      False  False  False  False
# Colorado  False  False   True   True
# Utah       True   True   True   True
# New York   True   True   True   True

# %%
data[data>5]
# Out:
#            one   two  three  four
# Ohio       NaN   NaN    NaN   NaN
# Colorado   NaN   NaN    6.0   7.0
# Utah       8.0   9.0   10.0  11.0
# New York  12.0  13.0   14.0  15.0

# %%
data[data>5]=0
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      0     0
# Utah        0    0      0     0
# New York    0    0      0     0

# %%
#loc, iloc
data.loc['Colorado', ['two', 'three']]
# Out:
# two      5
# three    0
# Name: Colorado, dtype: int64

# %%
data.iloc[2, [3, 0, 1]] #iloc = int index
# Out:
# four    0
# one     0
# two     0
# Name: Utah, dtype: int64

# %%
data.iloc[1]
# Out:
# one      4
# two      5
# three    0
# four     0
# Name: Colorado, dtype: int64

# %%
data.iloc[[1, 2], [3, 0, 1]]
# Out:
#           four  one  two
# Colorado     0    4    5
# Utah         0    0    0

# %%
data.loc[:'Utah', 'two']
# Out:
# Ohio        1
# Colorado    5
# Utah        0
# Name: two, dtype: int64

# %%
data.iloc[:, :3][data['three'] < 2]
#pull all row, and column [0,3) with column'three'<2
# Out:
#           one  two  three
# Colorado    4    5      0
# Utah        0    0      0
# New York    0    0      0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Integer Indexes

# %%
# if you have an axis index containing integers, data selection
#will always be label-oriented not position-based
ser = pd.Series(np.arange(3.))
ser
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# dtype: float64

# %%
ser[:1] #row [0,1)
# Out:
# 0    0.0
# dtype: float64

# %%
ser.iloc[:1] #for integer
# Out:
# 0    0.0
# dtype: float64

# %%
ser.loc[:1] #for label
# Out:
# 0    0.0
# 1    1.0
# dtype: float64

# %% [markdown]
# # Arithmetic and Data Alignment

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
                   index=['Ohio', 'Texas', 'Colorado'])
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])
df2
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1+df2 #join data
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list('abcd'))
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0

# %%
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                   columns=list('abcde'))
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df2.loc[1,'b']=np.nan
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   NaN   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df1+df2
# Out:
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0   NaN  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN

# %%
df1.add(df2, fill_value=0) #see table 5-5
# Out:
#       a     b     c     d     e
# 0   0.0   2.0   4.0   6.0   4.0
# 1   9.0   5.0  13.0  15.0   9.0
# 2  18.0  20.0  22.0  24.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
1 / df1
# Out:
#        a         b         c         d
# 0    inf  1.000000  0.500000  0.333333
# 1  0.250  0.200000  0.166667  0.142857
# 2  0.125  0.111111  0.100000  0.090909

# %%
df1.reindex(columns=df2.columns, fill_value=0)
# Out:
#      a    b     c     d  e
# 0  0.0  1.0   2.0   3.0  0
# 1  4.0  5.0   6.0   7.0  0
# 2  8.0  9.0  10.0  11.0  0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Operations between DataFrame and Series

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
series = frame.loc['Utah'] #= frame.iloc[0]
series
# Out:
# b    0.0
# d    1.0
# e    2.0
# Name: Utah, dtype: float64

# %%
frame - series #operation in each row
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0

# %%
series2 = pd.Series(range(3), index=['b', 'e', 'f'])
series2
# Out:
# b    0
# e    1
# f    2
# dtype: int64

# %%
frame+series2 
#row operation
#Union operation (if index not found: return nan)
# Out:
#           b   d     e   f
# Utah    0.0 NaN   3.0 NaN
# Ohio    3.0 NaN   6.0 NaN
# Texas   6.0 NaN   9.0 NaN
# Oregon  9.0 NaN  12.0 NaN

# %%
#column operation
series3 = frame['d']
series3
# Out:
# Utah       1.0
# Ohio       4.0
# Texas      7.0
# Oregon    10.0
# Name: d, dtype: float64

# %%
frame
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
frame.sub(series3, axis='index') # or axis=0
# Out:
#           b    d    e
# Utah   -1.0  0.0  1.0
# Ohio   -1.0  0.0  1.0
# Texas  -1.0  0.0  1.0
# Oregon -1.0  0.0  1.0

# %% [markdown]
# # Function Application and Mapping

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah   -1.276801  1.186389 -1.216590
# Ohio   -1.382672  0.296708 -1.846445
# Texas  -0.459063  0.307961 -0.504378
# Oregon  1.619818 -0.440375 -0.617634

# %%
np.abs(frame)
# Out:
#                b         d         e
# Utah    1.276801  1.186389  1.216590
# Ohio    1.382672  0.296708  1.846445
# Texas   0.459063  0.307961  0.504378
# Oregon  1.619818  0.440375  0.617634

# %%
f = lambda x: x.max() - x.min()
frame.apply(f, axis='columns') #row operation (weird)
# Out:
# Utah      2.463190
# Ohio      2.143153
# Texas     0.812338
# Oregon    2.237452
# dtype: float64

# %%
frame.apply(f, axis='index') #(column operation)
# Out:
# b    3.002490
# d    1.626765
# e    1.342068
# dtype: float64

# %%
def f(x):
  return pd.Series([x.min(), x.max()], index=['min', 'max'])
frame.apply(f)
# Out:
#             b         d         e
# min -1.382672 -0.440375 -1.846445
# max  1.619818  1.186389 -0.504378

# %%
#applymap 
format = lambda x: '%.2f' % x
frame.applymap(format)
# Out:
#             b      d      e
# Utah    -1.28   1.19  -1.22
# Ohio    -1.38   0.30  -1.85
# Texas   -0.46   0.31  -0.50
# Oregon   1.62  -0.44  -0.62

# %%
frame['e'].map(format)
# Out:
# Utah      -1.22
# Ohio      -1.85
# Texas     -0.50
# Oregon    -0.62
# Name: e, dtype: object

# %% [markdown]
# # Sorting and Ranking

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                     index=['three', 'one'],
                     columns=['d', 'a', 'b', 'c'])
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(axis='columns') #or axis = 1
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis=1, ascending=False) #reverse oder
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
obj = pd.Series([4, 7, -3, 2])
obj
# Out:
# 0    4
# 1    7
# 2   -3
# 3    2
# dtype: int64

# %%
obj.sort_values() #sort by values
# Out:
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj
# Out:
# 0    4.0
# 1    NaN
# 2    7.0
# 3    NaN
# 4   -3.0
# 5    2.0
# dtype: float64

# %%
obj.sort_values() #nan will be last
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a': [0, 1, 0, 1]})
frame
# Out:
#    b  a
# 0  4  0
# 1  7  1
# 2 -3  0
# 3  2  1

# %%
frame.sort_values(by='b')
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
frame.sort_values(by=['a', 'b'])
# Out:
#    b  a
# 2 -3  0
# 0  4  0
# 3  2  1
# 1  7  1

# %%
#rank function

obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj
# Out:
# 0    7
# 1   -5
# 2    7
# 3    4
# 4    2
# 5    0
# 6    4
# dtype: int64

# %%
obj.rank()
# Out:
# 0    6.5
# 1    1.0
# 2    6.5
# 3    4.5
# 4    3.0
# 5    2.0
# 6    4.5
# dtype: float64

# %%
obj.rank(method='first')
# Out:
# 0    6.0
# 1    1.0
# 2    7.0
# 3    4.0
# 4    3.0
# 5    2.0
# 6    5.0
# dtype: float64

# %%
obj.rank(ascending=False, method='max') #rank in reverse order, method = max
# Out:
# 0    2.0
# 1    7.0
# 2    2.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    4.0
# dtype: float64

# %%
frame = pd.DataFrame({'b': [4.3, 7, -3, 2], 'a': [0, 1, 0, 1],
                      'c': [-2, 5, 8, -2.5]})
frame
# Out:
#      b  a    c
# 0  4.3  0 -2.0
# 1  7.0  1  5.0
# 2 -3.0  0  8.0
# 3  2.0  1 -2.5

# %%
frame.rank(axis='columns')
# Out:
#      b    a    c
# 0  3.0  2.0  1.0
# 1  3.0  1.0  2.0
# 2  1.0  2.0  3.0
# 3  3.0  2.0  1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Axis Indexes with Duplicate Labels

# %%
obj = pd.Series(range(5), index=['a', 'a', 'b', 'b', 'c'])
obj
# Out:
# a    0
# a    1
# b    2
# b    3
# c    4
# dtype: int64

# %%
obj.index.is_unique
# Out:
# False

# %%
obj['a']
# Out:
# a    0
# a    1
# dtype: int64

# %%
df = pd.DataFrame(np.random.randn(4, 3), index=['a', 'a', 'b', 'b'])
df
# Out:
#           0         1         2
# a  1.328147  1.432832  0.707237
# a -0.041074 -0.482364 -0.884775
# b -1.599130 -2.749777 -0.824887
# b  0.385483  0.161188 -1.406394

# %%
df.loc['b']
# Out:
#           0         1         2
# b -1.599130 -2.749777 -0.824887
# b  0.385483  0.161188 -1.406394

# %% [markdown]
# # Summarizing and Computing Descriptive Statistics

# %%
 df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
                    [np.nan, np.nan], [0.75, -1.3]],
                   index=['a', 'b', 'c', 'd'],
                   columns=['one', 'two'])
 df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum(axis='columns') #sum by row (weird)
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.sum(axis='index') #sum by column
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.mean(axis='columns', skipna=False) #see skipna in table 5-7
# Out:
# a      NaN
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#idxmin and idxmax, return indirect statistics like the index value
#where the minimum or maximum values are attained
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %%
df.cumsum() #accumulate sum
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
obj = pd.Series(['a', 'a', 'b', 'c'] * 4)
obj
# Out:
# 0     a
# 1     a
# 2     b
# 3     c
# 4     a
# 5     a
# 6     b
# 7     c
# 8     a
# 9     a
# 10    b
# 11    c
# 12    a
# 13    a
# 14    b
# 15    c
# dtype: object

# %%
obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Correlation and Covariance

# %%
#returns.tail()
# returns['a'].corr(returns['b'])
#returns['a'].cov(returns['b'])
#returns.corr()
#returns.cov()

#see textbook for more detail

# %% [markdown]
# # Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
uniques.sort()
uniques
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
obj.value_counts() #count
# Out:
# c    3
# a    3
# b    2
# d    1
# dtype: int64

# %%
 pd.value_counts(obj.values, sort=False) #reverse oder counting
# Out:
# d    1
# a    3
# c    3
# b    2
# dtype: int64

# %%
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
mask = obj.isin(['b', 'c']) #boolean
mask
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
obj[mask]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
to_match = pd.Series(['c', 'a', 'b', 'b', 'c', 'a'])
to_match
# Out:
# 0    c
# 1    a
# 2    b
# 3    b
# 4    c
# 5    a
# dtype: object

# %%
unique_vals = pd.Series(['c', 'b', 'a'])
unique_vals
# Out:
# 0    c
# 1    b
# 2    a
# dtype: object

# %%
pd.Index(unique_vals).get_indexer(to_match) #return index in unique_val that appear in to_match
# Out:
# array([0, 2, 1, 1, 0, 2])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = pd.DataFrame({'Qu1': [1, 3, 4, 3, 4],
                     'Qu2': [2, 3, 1, 2, 3],
                     'Qu3': [1, 5, 2, 4, 4]})
data
# Out:
#    Qu1  Qu2  Qu3
# 0    1    2    1
# 1    3    3    5
# 2    4    1    2
# 3    3    2    4
# 4    4    3    4

# %%
result = data.apply(pd.value_counts).fillna(0) #count values [0-5] in each column
result
# Out:
#    Qu1  Qu2  Qu3
# 1  1.0  1.0  1.0
# 2  0.0  2.0  1.0
# 3  2.0  2.0  0.0
# 4  2.0  0.0  2.0
# 5  0.0  0.0  1.0
